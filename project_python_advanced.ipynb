# %%
#INTRODUCTION

#The california dataset is about the housing prices in the california place. Also here we can find data regarding prices due to locations near bay, ocean, islands.

#latitude( south to north(+))
#longitude (east to west(+)
#continuous       housing_median_age     median_income    median_house_value
#discrete         total_rooms            total_bedrooms   population              households
#nominal data       ocean_proximity



#TASK1
# 1. What is the average median income of the data set and check the distribution of data using appropriate plots.
#Please explain the distribution of the plot.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_excel("/content/2198208-housing_(1).xlsx")
#df1 = pd.DataFrame(df)
print(df)
print(df['median_income'].mean())

df.hist(bins=80,figsize=(20,20)) ##Histogram is used to see the distribution of a numerical value
plt.show()


# some graphs are having outliers
#while some graphs are skewed
# While latitude and logitude are not symmetric
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
#TASK2
#2. Draw an appropriate plot to see the distribution of housing_median_age and explain your observations.

plt.hist(df["housing_median_age"],color="blue")  #Histogram is used to see the distribution of a numerical value.#FF3845
plt.title("housing_median_age- Histogram plot")    # x-axis=housing_median_age,y-axis=Frequencies
plt.xlabel("housing_median_age")
plt.ylabel("Frequencies")

plt.show()

# HERE WE SEE IN THE HISTOGRAM THAT NEWLY BUILD HOUSES AND VERY OLD HOUSES ARE FEWER IN NUMBERS.
# distribution is near symmetric.

# %%
#TASK3
#3. Show with the help of visualization, how median_income and median_house_values are related?

# HERE WE USE THE SCATTER PLOT TO GET RELATION BETWEEN TWO PARAMETERS

sns.scatterplot(x="median_house_value",y="median_income",data=df)

#median_house_value is increasing with median income. also som extreme values are there i.e. outliers
# Out:
# <Axes: xlabel='median_house_value', ylabel='median_income'>

# %%
#TASK4
#4. Create a data set by deleting the corresponding examples from the data set for which
#total_bedrooms are not available.


df[df.isnull().any(axis=1)]        #MISSING VALUES DENOTED BY NaN

new_data=df.dropna(subset=["total_bedrooms"])   #MISSING VALUES DENOTED BY NaN are dropped

new_data

# here missing values are identified and then they are dropped and new data is created
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
#TASK5
#5. Create a data set by filling the missing data with the mean value of the total_bedrooms in the original data set.
a=df['total_bedrooms'].mean()                                # first mean is calculated
df["total_bedrooms"]=df["total_bedrooms"].fillna(a)       # now missing data in total bedrooms column is filled by mean calculated in the above code
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
a=df['total_bedrooms'].mean()
print(a)
# Out:
# 537.8705525375618

# %%
#TASK6
#6. Write a programming construct (create a user defined function) to
#    calculate the median value of the data set wherever required.

#Median gives the middle values when data is sorted

# %%
def medianvalue(columnname):
  median = df[columnname].median()
  return median

res1 = medianvalue('median_income')

print(res1)
# Out:
# 3.5347999999999997

# %%
res2 = medianvalue('housing_median_age')
print(res2)
# Out:
# 29.0

# %%
df['housing_median_age'].median()
# Out:
# 29.0

# %%
df['longitude'].median()
# Out:
# -118.49

# %%
df['latitude'].median()
# Out:
# 34.26

# %%
df['total_rooms'].median()
# Out:
# 2127.0

# %%
df['total_bedrooms'].median()
# Out:
# 438.0

# %%
df['population'].median()
# Out:
# 1166.0

# %%
df['households'].median()
# Out:
# 409.0

# %%
df['median_income'].median()
# Out:
# 3.5347999999999997

# %%
#TASK7
#7. Plot latitude versus longitude and explain your observations.
sns.scatterplot(x='latitude',y='longitude',data=df)

#from plot it is clear that the latitude and longitude are inversely correlated and as one increases other decreases(graph using seaborn library)
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
#TASK8
#8. Create a data set for which the ocean_proximity is ‘Near ocean’.

res1=df.loc[df["ocean_proximity"]=="NEAR OCEAN"]

print(res1)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1850     -124.17     41.80                  16         2739           480.0
# 1851     -124.30     41.80                  19         2672           552.0
# 1852     -124.23     41.75                  11         3159           616.0
# 1853     -124.21     41.77                  17         3461           722.0
# 1854     -124.19     41.78                  15         3140           714.0
# ...          ...       ...                 ...          ...             ...
# 20380    -118.83     34.14                  16         1316           194.0
# 20381    -118.83     34.14                  16         1956           312.0
# 20423    -119.00     34.08                  17         1822           438.0
# 20424    -118.75     34.18                   4        16704          2704.0
# 20425    -118.75     34.17                  18         6217           858.0
#
# ...

# %%
#TASK9
# 9. Find the mean and median of the median income for the data set created in question 8.

res1['median_income'].mean()     #clearly for hoouseholds near occean, mean income is more compared to the mean of all households
# Out:
# 4.0057848006019565

# %%
res1['median_income'].median()
# Out:
# 3.64705

# %%
#TASK10
#10. Please create a new column named total_bedroom_size. If the total bedrooms is 10 or less,
#     it should be quoted as small. If the total bedrooms is 11 or more but less than 1000, it should be medium, otherwise it should be considered large.

import numpy as np
conditions = [
              (df['total_bedrooms'] <=10),
              (df['total_bedrooms'] >=11)&(df['total_bedrooms'] <=1000),
              (df['total_bedrooms'] >=11)&(df['total_bedrooms'] > 1000)
             ]
values = ['small','medium','large']

df['total_bedroom_size']=np.select(conditions,values)

df


#results new column added where we get size category of the bedrooms
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...
